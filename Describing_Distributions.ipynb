# %% [markdown]
# ## **Imports**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy import stats

# %% [markdown]
# ### Load Data

# %%
Path ='data.csv'
df = pd.read_csv(Path)
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
# Find the mean
vit_mean = df['VitD_levels'].mean()
vit_mean
# Out:
# 17.99238089485999

# %% [markdown]
# ### Histogram with KDE VitD_level

# %%
sns.histplot(data=df, x='VitD_levels', discrete=True, stat='density', kde = True)
# Out:
# <AxesSubplot:xlabel='VitD_levels', ylabel='Density'>

# %%
col = 'VitD_levels'

# %%
def mean_graph(col):
    feature = df[col]
    mean = feature.mean()
    fig,ax = plt.subplots(figsize=(10,6))
    sns.histplot(feature ,ax=ax,stat='probability', kde= True)
    ax.axvline(mean,color = 'red', label=f'Mean = {mean:,.2f}',)
    ax.set_title(f'{col}')
    ax.legend();

# %%
def mean_median_graph(col):
    feature = df[col]
    mean = feature.mean()
    median = feature.median()
    fig,ax = plt.subplots(figsize=(10,6))
    sns.histplot(feature ,ax=ax,stat='probability', kde= True)
    ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
    ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
    ax.set_title(f'{col}')
    ax.legend()

# %%
def final_graph(col):
    feature = df[col]
    mean = feature.mean()
    median = feature.median()
    std = feature.std()
    plus_one_std = mean + std
    minus_one_std = mean - std
    fig,ax = plt.subplots(figsize=(10,6))
    sns.histplot(feature ,ax=ax,stat='probability', kde= True)
    ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
    ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
    ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
    ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
    ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
    ax.set_title(f'{col}')
    ax.legend()

# %%
print(mean_graph('VitD_levels'))
# Out:
# None

# %%
print(mean_median_graph('VitD_levels'))
# Out:
# None

# %%
print(final_graph('VitD_levels'))
# Out:
# None

# %%
from scipy import stats
kurt = stats.kurtosis(df['VitD_levels'], fisher = False)
print(kurt)
# Out:
# 3.013147515833447

# %% [markdown]
# - Is it Discrete or Continuous? It is Continuous
# - Does it have a skew? If so, which direction (+/-). No skew
# - Leptokurtic

# %% [markdown]
# ### Histogram with KDE DOC_Visit

# %%
print(mean_graph('Doc_visits'))
# Out:
# None

# %%
print(mean_median_graph('Doc_visits'))
# Out:
# None

# %%
print(final_graph('Doc_visits'))
# Out:
# None

# %%
from scipy import stats
kurt = stats.kurtosis(df['Doc_visits'], fisher = False)
print(kurt)
# Out:
# 2.9919958083381206

# %% [markdown]
# - Is it Discrete or Continuous? It is Discrete
# - Does it have a skew? If so, which direction (+/-). No skew
# - Platykurtic

# %% [markdown]
# ### Histogram with KDE TotalCharge

# %%
print(mean_graph('TotalCharge'))
# Out:
# None

# %%
print(mean_median_graph('TotalCharge'))
# Out:
# None

# %%
print(final_graph('TotalCharge'))
# Out:
# None

# %%
from scipy import stats
kurt = stats.kurtosis(df['TotalCharge'], fisher = False)
print(kurt)
# Out:
# 3.2650077463439393

# %% [markdown]
# - Is it Discrete or Continuous? It is Continuous
# - Does it have a skew? If so, which direction (+/-). Skew to the right (+)
# - Leptokurtic
